# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode
from torch.utils.data import DataLoader

# %%
from torchvision.io import read_image
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_dir = '/Users/david/Desktop/shelter_dogs_research/Data/trial5_raw/dataset'
dir_list = os.listdir(data_dir)
#check if DS_Store is in the list
if '.DS_Store' in dir_list:
    dir_list.remove('.DS_Store')
print(dir_list)
cat_path = os.path.join(data_dir, dir_list[0])
cat_list = os.listdir(cat_path)
if '.DS_Store' in cat_list:
    cat_list.remove('.DS_Store')
print(cat_list)
imgs_path = os.path.join(cat_path, cat_list[0])
img_list = os.listdir(imgs_path)
if '.DS_Store' in img_list:
    img_list.remove('.DS_Store')
print(img_list)
img_path = os.path.join(imgs_path, img_list[0])
img = Image.open(img_path)
img_size = img.size
print(img_size)
#find the smaller of the two dimensions
if img_size[0] < img_size[1]:
    min_dim = img_size[0]
else:
    min_dim = img_size[1]
print(min_dim)

data_transforms = {
    'train': transforms.Compose([
        transforms.CenterCrop(min_dim),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.CenterCrop(min_dim),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}


image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=8)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# ['test', 'train', 'val']
# ['standing', 'sitting', 'laying']
# ['83.jpg', '97.jpg', '68.jpg', '40.jpg', '54.jpg', '6.jpg', '78.jpg', '2.jpg', '50.jpg', '44.jpg', '93.jpg', '87.jpg', '86.jpg', '92.jpg', '45.jpg', '3.jpg', '51.jpg', '79.jpg', '47.jpg', '53.jpg', '1.jpg', '84.jpg', '90.jpg', '91.jpg', '85.jpg', '52.jpg', '0.jpg', '46.jpg']
# (1920, 1080)
# 1080

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    #self code
    ds_train_acc = {}
    ds_train_loss = {}
    ds_val_acc = {}
    ds_val_loss = {}
    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                #self code
                if phase == 'train':
                    train_loss = epoch_loss
                    train_acc = epoch_acc
                    ds_train_acc[epoch] = train_acc
                    ds_train_loss[epoch] = train_loss
                else:
                    val_loss = epoch_loss
                    val_acc = epoch_acc
                    ds_val_acc[epoch] = val_acc    
                    ds_val_loss[epoch] = val_loss               

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')
        
        libs = (ds_train_acc, ds_train_loss, ds_val_acc, ds_val_loss)  
        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model, libs

# %%
def visualize_train(model_ft, libs):
    ds_train_acc, ds_train_loss, ds_val_acc, ds_val_loss = libs
    #initialize the figure
    fig, axs = plt.subplots(1, 2, figsize=(15, 10))
    #plot the training accuracy in blue
    axs[0].plot(ds_train_acc.keys(), ds_train_acc.values(), 'b-')
    #plot the validation accuracy in a new color on the same graph
    axs[0].plot(ds_val_acc.keys(), ds_val_acc.values(), 'r-')
    axs[0].set_title("Accuracy")
    #set the legend and labels
    axs[0].legend(['Training Accuracy', 'Validation Accuracy'])
    #set the labels
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Accuracy')
    #plot the training loss in blue
    axs[1].plot(ds_train_loss.keys(), ds_train_loss.values(), 'b-')
    #plot the validation loss in a new color on the same graph
    axs[1].plot(ds_val_loss.keys(), ds_val_loss.values(), 'r-')
    axs[1].set_title("Loss")
    #set the legend and labels
    axs[1].legend(['Training Loss', 'Validation Loss'])
    #set the labels
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Loss')
    plt.show()
    return fig

# %%
model_ft = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
#fuction for exporting of model
def export_model(model, fig, model_dir):
    model_scripted = torch.jit.script(model)
    model_scripted.save(model_dir + '.pt')
    print(f"model exported to {model_dir}")
    #export figure as jpg
    fig.savefig(model_dir + '.jpg')
    print(f"figure exported to {model_dir + '.jpg'}")

# %%
model_ft, libs = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.9647 Acc: 0.5541
# val Loss: 0.9368 Acc: 0.7105
#
# Epoch 1/19
# ----------
# train Loss: 0.7310 Acc: 0.7344
# val Loss: 1.0875 Acc: 0.5789
#
# Epoch 2/19
# ----------
# train Loss: 0.6679 Acc: 0.7148
# val Loss: 0.7389 Acc: 0.5921
#
# Epoch 3/19
# ----------
# train Loss: 0.4825 Acc: 0.8098
# val Loss: 0.5904 Acc: 0.7632
#
# Epoch 4/19
# ----------
# train Loss: 0.4344 Acc: 0.8557
# val Loss: 0.5101 Acc: 0.8158
#
# Epoch 5/19
# ----------
# train Loss: 0.3901 Acc: 0.8525
# val Loss: 0.4254 Acc: 0.8421
#
# Epoch 6/19
# ----------
# train Loss: 0.3700 Acc: 0.8721
# val Loss: 0.3625 Acc: 0.8816
#
# Epoch 7/19
# ----------
# train Loss: 0.2727 Acc: 0.9279
# val Loss: 0.3733 Acc: 0.8421
#
# Epoch 8/19
# ----------
# train Loss: 0.2530 Acc: 0.9148
# val Loss: 0.3697 Acc: 0.8289
#
# Epoch 9/19
# ----------
# train Loss: 0.2646 Acc: 0.9049
# val Loss: 0.3563 Acc: 0.8289
#
# Epoch 10/19
# ----------
# train Loss: 0.2251 Acc: 0.9410
# val Loss: 0.3412 Acc: 0.8553
#
# Epoch 11/19
# ----------
# train Loss: 0.2240 Acc: 0.9443
# val Loss: 0.3311 Acc: 0.8816
#
# Epoch 12/19
# ----------
# train Loss: 0.2289 Acc: 0.9410
# val Loss: 0.3566 Acc: 0.8421
#
# Epoch 13/19
# ----------
# train Loss: 0.2073 Acc: 0.9443
# val Loss: 0.3402 Acc: 0.8421
#
# Epoch 14/19
# ----------
# train Loss: 0.2513 Acc: 0.9115
# val Loss: 0.3401 Acc: 0.8421
#
# Epoch 15/19
# ----------
# train Loss: 0.2083 Acc: 0.9475
# val Loss: 0.3467 Acc: 0.8289
#
# Epoch 16/19
# ----------
# train Loss: 0.2188 Acc: 0.9246
# val Loss: 0.3468 Acc: 0.8421
#
# Epoch 17/19
# ----------
# train Loss: 0.2436 Acc: 0.9377
# val Loss: 0.3430 Acc: 0.8421
#
# Epoch 18/19
# ----------
# train Loss: 0.2148 Acc: 0.9246
# val Loss: 0.3268 Acc: 0.8816
#
# Epoch 19/19
# ----------
# train Loss: 0.2287 Acc: 0.9016
# val Loss: 0.3477 Acc: 0.8421
#
# Training complete in 183m 30s
# Best val Acc: 0.881579

# %%
fig = visualize_train(model_ft, libs)

# %%
model_ft2 = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs2 = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft2.fc = nn.Linear(num_ftrs, len(class_names))

model_ft2 = model_ft.to(device)

criterion2 = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft2 = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler2 = lr_scheduler.StepLR(optimizer_ft2, step_size=7, gamma=0.1)

# %%
model_ft2, libs2 = train_model(model_ft2, criterion2, optimizer_ft2, exp_lr_scheduler2,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.2694 Acc: 0.9279
# val Loss: 0.4414 Acc: 0.8421
#
# Epoch 1/19
# ----------
# train Loss: 0.2747 Acc: 0.9213
# val Loss: 0.3393 Acc: 0.8816
#
# Epoch 2/19
# ----------
# train Loss: 0.2264 Acc: 0.9246
# val Loss: 0.3814 Acc: 0.8158
#
# Epoch 3/19
# ----------
# train Loss: 0.2542 Acc: 0.9115
# val Loss: 0.2610 Acc: 0.8816
#
# Epoch 4/19
# ----------
# train Loss: 0.1683 Acc: 0.9377
# val Loss: 0.2580 Acc: 0.8816
#
# Epoch 5/19
# ----------
# train Loss: 0.1602 Acc: 0.9443
# val Loss: 0.2187 Acc: 0.9079
#
# Epoch 6/19
# ----------
# train Loss: 0.1619 Acc: 0.9443
# val Loss: 0.2350 Acc: 0.9211
#
# Epoch 7/19
# ----------
# train Loss: 0.1264 Acc: 0.9475
# val Loss: 0.2023 Acc: 0.8947
#
# Epoch 8/19
# ----------
# train Loss: 0.1287 Acc: 0.9705
# val Loss: 0.1939 Acc: 0.8947
#
# Epoch 9/19
# ----------
# train Loss: 0.1140 Acc: 0.9738
# val Loss: 0.1948 Acc: 0.8947
#
# Epoch 10/19
# ----------
# train Loss: 0.1066 Acc: 0.9672
# val Loss: 0.2114 Acc: 0.8947
#
# Epoch 11/19
# ----------
# train Loss: 0.1036 Acc: 0.9607
# val Loss: 0.2081 Acc: 0.8947
#
# Epoch 12/19
# ----------
# train Loss: 0.1209 Acc: 0.9705
# val Loss: 0.1924 Acc: 0.9079
#
# Epoch 13/19
# ----------
# train Loss: 0.1087 Acc: 0.9836
# val Loss: 0.1984 Acc: 0.8947
#
# Epoch 14/19
# ----------
# train Loss: 0.1206 Acc: 0.9607
# val Loss: 0.1923 Acc: 0.8947
#
# Epoch 15/19
# ----------
# train Loss: 0.1018 Acc: 0.9770
# val Loss: 0.1916 Acc: 0.8947
#
# Epoch 16/19
# ----------
# train Loss: 0.0988 Acc: 0.9705
# val Loss: 0.1957 Acc: 0.8684
#
# Epoch 17/19
# ----------
# train Loss: 0.1019 Acc: 0.9607
# val Loss: 0.1945 Acc: 0.8684
#
# Epoch 18/19
# ----------
# train Loss: 0.0947 Acc: 0.9770
# val Loss: 0.2137 Acc: 0.8816
#
# Epoch 19/19
# ----------
# train Loss: 0.1269 Acc: 0.9541
# val Loss: 0.2215 Acc: 0.8947
#
# Training complete in 985m 59s
# Best val Acc: 0.921053

# %%
fig2 = visualize_train(model_ft2, libs2)

# %%
export_model(model_ft, fig, '/Users/david/Desktop/shelter_dogs_research/Data/trial5_raw/trial5_docs/model5.3')
# Out:
# model exported to /Users/david/Desktop/shelter_dogs_research/Data/trial5_raw/trial5_docs/model5.3
# figure exported to /Users/david/Desktop/shelter_dogs_research/Data/trial5_raw/trial5_docs/model5.3.jpg

# %%
export_model(model_ft2, fig, '/Users/david/Desktop/shelter_dogs_research/Data/trial5_raw/trial5_docs/model5.3b')
# Out:
# model exported to /Users/david/Desktop/shelter_dogs_research/Data/trial5_raw/trial5_docs/model5.3b
# figure exported to /Users/david/Desktop/shelter_dogs_research/Data/trial5_raw/trial5_docs/model5.3b.jpg

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(model_ft)

plt.ioff()
plt.show()

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    print(img.size)
    img = img.convert('RGB')
    print(img.size)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
   # plt.imshow(img)

    print(img.size)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
visualize_model_predictions(model_ft, '/Users/david/Desktop/shelter_dogs_research/Data/trial1_pup1/trial1.1/test/standing/87.jpg')
# Out:
# (500, 500)
# (500, 500)
# <built-in method size of Tensor object at 0x16c1f4540>
