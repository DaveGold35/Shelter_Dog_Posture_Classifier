# %%
#do not run unless new environment is created
#%pip install torch==1.13.0
#%pip install opencv-python
#%pip install torchvision==0.14.0
#%pip install opencv-python

# %%
import torch
import torchvision
print('torch version: ', torch.__version__)
print('torchvision version: ', torchvision.__version__)

import cv2
print('cv2 version: ', cv2.__version__)
# Out:
# torch version:  1.13.0
# torchvision version:  0.14.0
# cv2 version:  4.8.0

# %%
#print torch version
print(torch.__version__)
#print opencv version
print(cv2.__version__)
#print torchvision version  
print(torchvision.__version__)
# Out:
# 1.13.0
# 4.8.0
# 0.14.0

# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from os import path
import os

# %%
from torchvision.models.detection import maskrcnn_resnet50_fpn
from torchvision.transforms import functional as F

# %%
model = maskrcnn_resnet50_fpn(pretrained=True)
model.eval()
# Out:
# /Users/david/anaconda3/envs/python3_9dis/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/david/anaconda3/envs/python3_9dis/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(14, 14), sampling_ratio=2)
#     (mask_head): MaskRCNNHeads(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(256, 91, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
#   PROCEDURE:  IMPORT_PIC(PATH)    OUTPUT: IMG, COPY

def import_pic(path):
    img = cv2.imread(path)
    copy = img.copy()
    return img, copy

# %%
#   PROCEDURE:  TO_TENSOR(IMG)  OUTPUT: IMAGE_TENSOR

def to_tensor(img):
    image_tensor = F.to_tensor(img)
    return image_tensor

# %%
#   PROCEDURE:  MAKE_PREDICTION(IMAGE_TENSOR, MODEL)    OUTPUT: PREDICTION

def make_prediction(image_tensor, model):
    prediction = model([image_tensor])
    return prediction

# %%
#   PROCEDURE:  BOUNDING_OBJECTS(PREDICTION)    OUTPUT: BOXES, LABELS, MASKS

def bounding_objects(prediction):
    boxes = prediction[0]['boxes']
    labels = prediction[0]['labels']
    masks = prediction[0]['masks']
    return boxes, labels, masks

# %%
#   PROCEDURE:  APPLY(IMAGE, BOXES, LABELS, MASKS)  OUTPUT: IMAGE

def apply(image, boxes, labels, masks):
    for i in range(len(boxes)):
        if labels[i] == 18:
            box = boxes[i].detach().numpy()
            mask = masks[i, 0].detach().numpy()
            mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

            mask = mask.astype(image.dtype)

            image = cv2.rectangle(image, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), (0, 255, 0), 2)
            image = cv2.addWeighted(image, 0.5, mask, 0.5, 0)

#    plt.figure(figsize=(20, 20))
#    plt.imshow(image)
#    plt.axis('off')
#    plt.show()
    return image

# %%
#   PROCEDURE: FIND_LARGEST_BOX(BOXES)  OUTPUT: LARGEST_BOX_COORD

def find_largest_box(boxes):
    largest_box = 0
    for i in range(len(boxes)):
        box = boxes[i].detach().numpy()
        if (box[2]-box[0])*(box[3]-box[1]) > largest_box:
            largest_box = (box[2]-box[0])*(box[3]-box[1])
            largest_box_coord = box
    if largest_box == 0:
        largest_box_coord = [0,0,0,0]
    return largest_box_coord

# %%
#   PROCEDURE: CROP(IMG, BOX_COORD, SIZE) OUTPUT: CROP_IMG

def crop(img, box_coord, size):
    v_size = box_coord[3] - box_coord[1]
    h_size = box_coord[2] - box_coord[0]

    assert v_size < size, ("dog object larger than cropping size vertically", v_size, ' > ', size)
    assert h_size < size,("dog object is larger than cropping size horizontally", h_size , ' > ' , size)

    v_diff = size - v_size
    h_diff = size - h_size

    half_vdiff = v_diff/2
    half_hdiff = h_diff/2

    new_coord0 = box_coord[0] - half_hdiff
    new_coord1 = box_coord[1] - half_vdiff
    new_coord2 = box_coord[2] + half_hdiff
    new_coord3 = box_coord[3] + half_vdiff
    
    if new_coord0 < 0:
        new_coord0 = 0
        new_coord2 = size

    if new_coord1 < 0:
        new_coord1 = 0
        new_coord3 = size

    if new_coord2 > img.shape[1]:
        new_coord0 = img.shape[1] - size
        new_coord2 = img.shape[1]

    if new_coord3 > img.shape[0]:
        new_coord1 = img.shape[0] - size
        new_coord3 = img.shape[0]

    crop_img = img[int(new_coord1) : int(new_coord3),int(new_coord0) : int(new_coord2)]
    return crop_img

# %%
#   PROCEDURE: EXPORT(IMG, NAME, EP)    OUTPUT: BOOLEAN

def export(img, name, ep):
    if not os.path.exists(ep):
        os.makedirs(ep)

    path = ep + '/' + name + '.jpg'
    cv2.imwrite(path, img)
    #check if image was sucessfully written
    if os.path.isfile(path):
        
        return True
    else:
        
        return False

# %%
#  PROCEDURE: PIPELINE(MODEL, IP, NAME, EP, SIZE)    OUTPUT: BOOLEAN

def pipeline(model, ip, name, ep, size=500):
    img, copy = import_pic(ip)
    image_tensor = to_tensor(img)
    prediction = make_prediction(image_tensor, model)
    boxes, labels, masks = bounding_objects(prediction)
    applied_img = apply(copy, boxes, labels, masks)
    largest = find_largest_box(boxes)
    cropped = crop(img, largest, size)
    exported = export(cropped, name, ep)

    
    #plt.imshow(cropped)
    #plt.axis('off')
    #plt.show()

    if exported == True:
        print('Cropped image successfully exported as :', name, '.jpg \n ~~to the folder: ', ep)
        return True
    else:
        print('Export failed, please try again')

# %% [markdown]
# Runtime trial

# %%
pipeline(model, '/Users/david/Desktop/shelter_dogs_research/Trials/trial3_pup1_env12/trial run/0.jpg', 'trial','/Users/david/Desktop/shelter_dogs_research/Trials/trial3_pup1_env12/trial run')
# Out:
# Cropped image successfully exported as : trial .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Trials/trial3_pup1_env12/trial run
# True

# %%
#  PROCEDURE: ITER_PIP(MODEL, IP, EP, END, START, COUNTER_START)    OUTPUT: NONE

def iter_pip(model, ip, ep, end, start= 0, counter_start=0):
    i = start
    counter = counter_start
    
    while i < end:
        try:
            img_path = ip + '/' + str(i) + '.jpg'
            pipeline(model, img_path, str(counter), ep)
        
        except AssertionError as e:
            print(e)
            print('Image skipped')
            pass
        counter += 1
        i += 1

# %%
iter_pip(model,
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/frames/laying', 
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying', 
        194)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 iter_pip(model,
#       2         '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/frames/laying',
#       3         '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying',
#       4         194)
#
# Cell In[16], line 10, in iter_pip(model, ip, ep, end, start, counter_start)
#       8 try:
#       9     img_path = ip + '/' + str(i) + '.jpg'
# ---> 10     pipeline(model, img_path, str(counter), ep)
#      12 except AssertionError as e:
#      13     print(e)
#
# Cell In[15], line 10, in pipeline(model, ip, name, ep, size)
#       8 applied_img = apply(copy, boxes, labels, masks)
#       9 largest = find_largest_box(boxes)
# ---> 10 cropped = crop(img, largest, size)
#      11 exported = export(cropped, name, ep)
#      14 #plt.imshow(cropped)
#      15 #plt.axis('off')
#      16 #plt.show()
#
# Cell In[13], line 4, in crop(img, box_coord, size)
#       3 def crop(img, box_coord, size):
# ----> 4     v_size = box_coord[3] - box_coord[1]
#       5     h_size = box_coord[2] - box_coord[0]
#       7     assert v_size < size, ("dog object larger than cropping size vertically", v_size, ' > ', size)
#
# IndexError: invalid index to scalar variable.

# %%
iter_pip(model,
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/frames/laying', 
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying', 
        start = 148,
        counter_start= 148,
        end = 194)
# Out:
# Cropped image successfully exported as : 148 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 149 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 150 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 151 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 152 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 153 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 154 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 155 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 156 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 157 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 158 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 159 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 160 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 161 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 162 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 163 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 164 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 165 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 166 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# ('dog object is larger than cropping size horizontally', 1156.187, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 168 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 169 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 170 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 171 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 172 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 173 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 174 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 175 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 176 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 177 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 178 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 179 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 180 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 181 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 182 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 183 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 184 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 185 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 186 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 187 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 188 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 189 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 190 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 191 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 192 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying
# Cropped image successfully exported as : 193 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/laying

# %%
iter_pip(model,
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/frames/sitting', 
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting', 
        144)
# Out:
# Cropped image successfully exported as : 0 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 1 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 2 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 3 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 4 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 5 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 6 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 7 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 8 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 1067.9668, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 10 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 11 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 12 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 13 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 1071.8969, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 1064.3685, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 16 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 17 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 18 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 19 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 20 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 21 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 22 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 23 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 24 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 25 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 26 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 27 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 28 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 1071.8969, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 1068.3563, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 31 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 32 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 33 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 34 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 35 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 36 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 37 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 958.6726, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 39 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 40 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 41 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 42 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 43 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 44 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 45 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 46 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 554.58813, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 658.44116, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 663.683, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 614.3098, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 618.03656, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 647.089, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 553.05505, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 566.5502, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 582.8125, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 643.1626, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 619.1776, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 633.8594, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 598.0128, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 554.2919, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 548.50146, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 62 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 551.4662, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 538.3157, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 597.63525, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 551.43677, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 538.4558, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 68 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 69 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 70 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 524.55804, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 72 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 73 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 74 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 75 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 76 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 77 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 78 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 79 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 80 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 81 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 82 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 83 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 84 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 85 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 86 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 87 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 88 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 89 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 90 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 91 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 92 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 93 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 94 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 95 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 616.7134, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 97 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 861.7365, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 99 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 594.6593, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 845.0148, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 102 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 103 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 104 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 105 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 106 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 107 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 108 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 109 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 566.1092, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 584.4216, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 112 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 113 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 114 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 523.6904, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 116 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 117 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 118 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 119 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 583.1275, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 573.8218, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 631.7075, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 123 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 124 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 125 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object larger than cropping size vertically', 571.67236, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 570.48035, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 128 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 129 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object is larger than cropping size horizontally', 512.2097, ' > ', 500)
# Image skipped
# ('dog object is larger than cropping size horizontally', 527.71796, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 132 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 133 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 134 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 135 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# ('dog object is larger than cropping size horizontally', 517.36395, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 137 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 138 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 139 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 140 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 141 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 142 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting
# Cropped image successfully exported as : 143 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/sitting

# %%
iter_pip(model,
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/frames/standing', 
        '/Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing', 
        137)
# Out:
# ('dog object is larger than cropping size horizontally', 506.93994, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 1 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object is larger than cropping size horizontally', 500.20117, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 3 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 4 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 5 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 6 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 7 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 8 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 9 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 10 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 11 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 12 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 13 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 14 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 15 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 16 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 17 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 18 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 19 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 20 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 21 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 22 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 23 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 24 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 25 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 26 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 27 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 28 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 29 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 30 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 31 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 32 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 33 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 34 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 35 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 36 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 37 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 38 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 39 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 40 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 41 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 42 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 43 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 44 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 45 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 46 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 47 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 48 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 545.8589, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 50 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 51 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 52 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 53 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 54 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 55 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 56 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 591.5311, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 58 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 59 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 60 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 61 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 62 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 63 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 64 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 702.1174, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 66 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 67 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 68 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 500.3189, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 513.27686, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 71 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 518.53925, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 505.61395, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 560.8183, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 539.98755, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 560.8769, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 77 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 78 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 79 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 80 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 81 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 82 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 83 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 84 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 85 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 509.94354, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 87 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 88 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 89 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 90 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 91 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 92 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 93 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 94 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 95 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 96 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 599.83984, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 98 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object larger than cropping size vertically', 908.9687, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 658.1218, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 883.7231, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 576.60986, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 568.52313, ' > ', 500)
# Image skipped
# ('dog object is larger than cropping size horizontally', 985.52405, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 861.96643, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 723.39514, ' > ', 500)
# Image skipped
# ('dog object is larger than cropping size horizontally', 542.16016, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 624.1454, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 631.19556, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 598.5476, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 724.5861, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 635.0795, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 644.73474, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 611.41284, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 704.54083, ' > ', 500)
# Image skipped
# ('dog object larger than cropping size vertically', 529.62, ' > ', 500)
# Image skipped
# Cropped image successfully exported as : 117 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 118 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 119 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 120 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 121 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 122 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 123 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 124 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 125 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 126 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 127 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 128 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 129 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 130 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 131 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 132 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 133 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 134 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# Cropped image successfully exported as : 135 .jpg
#  ~~to the folder:  /Users/david/Desktop/shelter_dogs_research/Data/trial3_pup1_env12/cropped/standing
# ('dog object is larger than cropping size horizontally', 634.1512, ' > ', 500)
# Image skipped
